# %% [markdown]
# # spotify data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max.columns', None)

# %% [markdown]
# ##Import the datasets

# %%
tracks=pd.read_csv('C:/Users/Dell E5470/Desktop/kaggle exercises/spotify/tracks.csv')
tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
## check nulls
pd.isnull(tracks).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %%
## top ten least popular songs
sorted_popularity=tracks.sort_values('popularity', ascending=True).head(10)
sorted_popularity
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %%
most_popular=tracks.query('popularity>90',inplace=False).sort_values('popularity', ascending=False).head(20)
most_popular
# Out:
#                            id  \
# 93802  4iJyoBOLtHqaGxP12qzhQI
# 93803  7lPN2DXiMsVn7XUKtOW1CS
# 93804  3Ofmpyhv5UAQ70mENzB277
# 92810  5QO79kh1waicV47BqGRL3g
# 92811  6tDDoYIxWvMLTdKpjFkc1B
# 92813  0VjIjW4GlUZAMYd2vXMi3b
# 93805  7MAibcTli4IisCtbHKrGMh
# 92814  6f3Slt0GbA2bPZlz0aIFXN
# 91866  60ynsPSSKe6O3sfwRnIBRf
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp
# 92817  27OeeYzk6klgBh83TSvGMA
# 92819  1xK1Gg9SxG8fy2Ya373oqb
# 93807  4cG7HUWYHBV6R6tHn1gxrl
# 93806  7Bk0uXKk1uPT0XuQbpFzvs
# 92821  2XIc1pqjXV3Cr2BQUGNBck
# 92823  3YJJjQPAbDT7mGpX3WtQ9A
# 93812  3iw6V4LH7yPj1ESORX9RIN
# 93810  5uEYRdEIh9Bo4fpjDd4Na9
# 93811  4u4NyuceXP7Uzh7XFJKCr1
# 92829  6ft4hAq6yde8jPZY2i5zLr
#
#                                                     name  popularity  \
# 93802             Peaches (feat. Daniel Caesar & Giveon)         100
# 93803                                    drivers license          99
# 93804                             Astronaut In The Ocean          98
# ...

# %%
tracks.set_index('release_date', inplace=True)
tracks.index=pd.to_datetime(tracks.index)
tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922-01-01             0       163080         0      ['Dick Haymes']
#
# ...

# %%
tracks[['artists']].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: 1922-01-01 00:00:00, dtype: object

# %%
 #convert milliseconds to second
tracks['duration']=tracks['duration'].apply(lambda x:round(x*10))
tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  explicit              artists  \
# release_date
# 1922-02-22             6         0              ['Uli']
# 1922-06-01             0         0  ['Fernando Pessoa']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-03-21             0         0  ['Ignacio Corsini']
# 1922-01-01             0         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# ...

# %%
corr_df=tracks.drop(['key','mode','explicit','duration'], axis=1).corr(method='pearson')
plt.figure(figsize=(8,6))
heatmap=sns.heatmap(corr_df, annot=True,fmt='.1g',vmin=1, vmax=1,center=0, cmap='inferno',linewidth=1, linecolor='Black')
heatmap.set_title("correlation heatmap")
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
plt.show()

# %%
sample_df=tracks.sample(int(0.004*len(tracks)))

# %%
print(len(sample_df))
# Out:
# 2346

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=sample_df, y="loudness", x="energy", color="c").set(title="corr btn Loudness and energy")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=sample_df, y="popularity", x="acousticness", color="b").set(title="corr btn popularity and acousticness")
plt.show()

# %%
tracks['dates']=tracks.index.get_level_values('release_date')
tracks.date=pd.to_datetime(tracks.dates)
years=tracks.dates.dt.year
# Out:
# C:\Users\Dell E5470\AppData\Local\Temp\ipykernel_10496\572749233.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   tracks.date=pd.to_datetime(tracks.dates)

# %%
sns.distplot(years,color='b').set(title='Number of songs per year')
# Out:
# C:\Users\Dell E5470\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 1.0, 'Number of songs per year')]

# %%
total_dr= tracks.duration
fig_dims=(18,7)
fig, ax=plt.subplots(figsize=fig_dims)
fig=sns.barplot(x=years, y=total_dr, ax=ax, errwidth=False).set(title='Year vs Duration')
plt.xticks(rotation=90)
plt.show()

# %%
#total_dr=tracks.duration
#sns.set_style(style="whitegrid")
#fig_dims=(10, 5)
#fig, ax=plt.subplots(figsize=fig_dims)
#fig=sns.lineplot(x=years, y=total_dr, ax=ax).set(title="year vs duration")
#plt.xticks(rotation=60)

# %%
features=pd.read_csv('C:/Users/Dell E5470/Desktop/kaggle exercises/spotify/SpotifyFeatures.csv')
features.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
plt.title("duration of songs in different genres")
sns.color_palette("rocket", as_cmap=True)
sns.barplot(y="genre", x="duration_ms", data=features)
plt.xlabel("Duratio(ms)")
plt.ylabel("genre")
# Out:
# Text(0, 0.5, 'genre')

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(8,6))
famous=features.sort_values("popularity", ascending=False).head(10)
sns.barplot(y="genre", x="popularity",data=famous).set(title="genre by popularity")
# Out:
# [Text(0.5, 1.0, 'genre by popularity')]
